# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA

# %%
asset = os.path.join("~", "study", "RAL", "data")
df_name =  "_ral_multi_class_{ds}_{ep}.csv".format(ds = "white", ep = 2)
df_train = pd.read_csv(os.path.join(asset, "df_train" + df_name))
df_pool = pd.read_csv(os.path.join(asset, "df_pool" + df_name))
df_test = pd.read_csv(os.path.join(asset, "df_test" + df_name))

rfc = RandomForestClassifier(
                n_estimators=500, max_depth=10, oob_score= True, random_state=0
                )
label = '6'
X_test = df_test.loc[:,df_test.columns[df_test.columns != label]].values
y_test = df_test.loc[:, label].values
X_train= df_train.loc[:,df_train.columns[df_train.columns != label]].values
y_train= df_train.loc[:, label].values
X_pool = df_pool.loc[:,df_pool.columns[df_pool.columns != label]].values
y_pool = df_pool.loc[:, label].values

len(df_pool)
# Out:
# 1218

# %%
cl_var

# %%
df =  pd.read_csv(os.path.join("data","adult.csv"),header=None)
len(df[(100+10):])
